# %% [markdown]
# # Capítol 3 - Algorismes i Nombres

# %% [markdown]
# ### 3.10 Restriccions múltiples o operacions amb condicions

# %% [markdown]
# Fes una funció que trobi el nombre $n$ més gran tal que compleixi les tres condicions seg¨üents:
# + $n<10000$
# + $n = m^2$ per algun $m$
# + $n = k! + 1$ per algun $k$

# %%
import math
def numero_3_condicions():
    """
    Aquesta funció troba els numeros que compleixen les tres condicions demanades
    
    Returns
    -------
    buscat: int
    """
    buscat = 0
    llista = llistafactorial(10000)
    trobat = False
    for num in llista:
        for x in range (10000):
            if num == x*x:
                buscat = num
    return buscat

# %%
assert numero_3_condicions() == 5041

# %% [markdown]
# Fes una funció que trobi tots els nombres de setmanes $n$ que tinguin un nombre de segons $s$ tal que $s=k!$ per algun $k<100$.

# %%
import math

def setmanes_segons():
    """
    Aquesta funció troba tots els nombres de setmanes N que tenen 
    un nombre de segons S tal que S = K! per algun k < 100
    
    Returns
    -------
    res: list
    """
    n_setmanes = []
    setmana = 604800
    a = 1
    for i in llistafactorialfins(100):
        print(i)
        if i > setmana:
            while a < i:
                if i == a*setmana:
                    n_setmanes.append(a)
                a += 1
    
        
    return n_setmanes

# %%
assert setmanes_segons() == [6, 66, 792]
# Out:
# 1
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800
# 39916800
# 479001600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 assert setmanes_segons() == [6, 66, 792]
#
# Cell In[26], line 18, in setmanes_segons()
#      16 print(i)
#      17 if i > setmana:
# ---> 18     while a < i:
#      19         if i == a*setmana:
#      20             n_setmanes.append(a)
#
# KeyboardInterrupt:

# %% [markdown]
# Donat un nombre $n$, troba dos nombres positius tals que la suma dels seus quadrats sigui $n$, o si no n'hi ha que retorni $(-1, -1)$.

# %%
import math
def quadrats(n):
    """
    Aquesta funció troba dos nombres positius tals que la suma 
    dels seus quadrats sigui n.
    
    Parameters
    ----------
    n: int
    
    Returns
    -------
    quadrats: (int, int)
    """

# %%
assert quadrats(125) == (2,11)
assert quadrats(106) == (5,9)
assert quadrats(81) == (-1,-1)

# %% [markdown]
# Els nombres naturals menors que 10 que són múltiples de 3 o 5 són 3, 5, 6 i 9. La seva suma és 23. Troba la suma de tots els nombres naturals menors que 1000 que són múltiples de 3 o 5.

# %%
def multiples():
    """
    Aquesta funció retorna la suma de tots els naturals que 
    són múltiples de 3 o 5 i que son menors de 1000.
    
    Returns
    -------
    suma : int
    """

# %%
assert multiples() == 233168

# %%
import math 

def llistafactorial (n):
    llista =[]
    num = 1
    while math.factorial(num) < n:
       llista.append(math.factorial(num)+1)
       num += 1
    return llista

# %%
llistafactorial(10000)
# Out:
# [2, 3, 7, 25, 121, 721, 5041]

# %%
import math
def llistasetmanes():
    setmana = 604800
    llista=[]
    a = 1
    while a <= (math.factorial(100)/setmana):
        llista.append(a*setmana)
        a += 1
    return llista

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 setmanes_segons()
#
# Cell In[19], line 17, in setmanes_segons()
#      15 for i in llistafactorialfins(100):
#      16     if i > setmana:
# ---> 17         while a <= int(i/setmana):
#      18             if i == a*setmana:
#      19                 n_setmanes.append(a)
#
# KeyboardInterrupt:
